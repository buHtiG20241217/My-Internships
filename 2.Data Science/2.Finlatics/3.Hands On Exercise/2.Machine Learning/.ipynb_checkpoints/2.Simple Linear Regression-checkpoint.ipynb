# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the Dataset

# %%
dataset_df = pd.read_csv('2.Simple_Linear_Regression.csv')

# %%
dataset_df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %% [markdown]
# ## Splitting the Dataset

# %%
x = dataset_df.iloc[:,:-1].values
y = dataset_df.iloc[:,-1].values

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %% [markdown]
# ### Training and Testing Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state=1)

# %%
x_train
# Out:
# array([[ 9.5],
#        [ 2. ],
#        [ 8.7],
#        [ 7.9],
#        [ 8.2],
#        [ 2.2],
#        [ 1.5],
#        [ 9. ],
#        [ 3. ],
#        [ 5.9],
#        [ 4.1],
#        [ 3.2],
#        [ 9.6],
#        [ 1.3],
#        [ 5.1],
#        [ 1.1],
#        [ 4.9],
#        [10.5],
#        [10.3],
#        [ 3.7],
#        [ 3.2],
#        [ 4. ],
#        [ 4. ],
#        [ 2.9]])

# %%
x_test
# Out:
# array([[5.3],
#        [7.1],
#        [3.9],
#        [6. ],
#        [4.5],
#        [6.8]])

# %%
y_train
# Out:
# array([116969.,  43525., 109431., 101302., 113812.,  39891.,  37731.,
#        105582.,  60150.,  81363.,  57081.,  54445., 112635.,  46205.,
#         66029.,  39343.,  67938., 121872., 122391.,  57189.,  64445.,
#         56957.,  55794.,  56642.])

# %%
y_test
# Out:
# array([83088., 98273., 63218., 93940., 61111., 91738.])

# %% [markdown]
# ## Training the Model

# %% [markdown]
# ![image.png](attachment:28a38c5f-c18f-496f-9c4d-d3b68172e78a.png)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the test set result

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred,y_test
# Out:
# (array([75074.50510972, 91873.8056381 , 62008.38247653, 81607.56642631,
#         67608.14931932, 89073.92221671]),
#  array([83088., 98273., 63218., 93940., 61111., 91738.]))

# %%
np.concatenate([y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)],axis = 1)
# Out:
# array([[75074.50510972, 83088.        ],
#        [91873.8056381 , 98273.        ],
#        [62008.38247653, 63218.        ],
#        [81607.56642631, 93940.        ],
#        [67608.14931932, 61111.        ],
#        [89073.92221671, 91738.        ]])

# %% [markdown]
# ## Visualizing the Training set results

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='purple')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary of Employee')
plt.grid()
plt.show()

# %% [markdown]
# ## Visualizing the Testing set results

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='purple')
plt.title('Salary vs Experience (Testing set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary of Employee')
plt.grid()
plt.show()

# %% [markdown]
# ## Simple Linear Regression Done Yay !
